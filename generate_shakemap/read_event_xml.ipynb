# %%
#   scevtstreams -E ies2026duod -d mysql://sysop:sysop@192.168.11.250/seiscomp -m 120,180 -R --all-stations | scart --list - -I fdsnws://192.168.11.250:8080 ./archive

# %%
# scevtstreams -E ies2026duod -d mysql://sysop:sysop@192.168.11.250/seiscomp -m 300 -R --all-stations > st.xml

# %%
from obspy import read, read_inventory  

# Read waveform file
fl_name = "./archive/GO/AZNN/HHZ.D/GO.AZNN.00.HHZ.D.2026.054"
st = read(fl_name)

# Preview metadata
print(st[0].stats)
print("___________________")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from obspy import read, read_inventory
#       3 # Read waveform file
#       4 fl_name = "./archive/GO/AZNN/HHZ.D/GO.AZNN.00.HHZ.D.2026.054"
#
# File ~/Code/Seiscomp_Scripts/env/lib/python3.12/site-packages/obspy/__init__.py:44
#      41     msg = ('pkg_resources is deprecated as an API')
#      42     warnings.filterwarnings(
#      43         'ignore', message=msg, category=DeprecationWarning, module='obspy')
# ---> 44     from obspy.core.utcdatetime import UTCDateTime  # NOQA
#      45 from obspy.core.util import _get_version_string
#      46 __version__ = _get_version_string(abbrev=10)
#
# File ~/Code/Seiscomp_Scripts/env/lib/python3.12/site-packages/obspy/core/__init__.py:120
#      12 """
#      13 obspy.core - Core classes of ObsPy
#      14 ==================================
# ...
